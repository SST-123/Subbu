# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir(r'C:\Users\admin\Desktop\GS') #setting the path

# %%
google_stock = pd.read_csv('Goo_stock.csv',index_col = 0) #first column becomes the index column

# %%
google_stock.head() #defaulty first five rows
# Out:
#                 Open       High        Low      Close  Adj Close    Volume
# Date
# 8/19/2004  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 8/20/2004  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 8/23/2004  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 8/24/2004  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 8/25/2004  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
google_stock = pd.read_csv('Goo_stock.csv')
google_stock.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0  8/19/2004  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 1  8/20/2004  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2  8/23/2004  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 3  8/24/2004  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 4  8/25/2004  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
google_stock.tail() #last five rows
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3308   10/9/2017  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  10/10/2017  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  10/11/2017  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  10/12/2017  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  10/13/2017  992.000000  997.210022  989.000000  989.679993  989.679993
#
#        Volume
# 3308   891400
# 3309   968400
# 3310  1693300
# 3311  1262400
# 3312  1157700

# %%
samp = google_stock.copy(deep = False) #if we made any changes to the 'samp', original DataFrame also changes

# %%
google_stock.index #row index labels
# Out:
# RangeIndex(start=0, stop=3313, step=1)

# %%
google_stock.columns #column index labels
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
google_stock.shape #total no of rows and total no of columns
# Out:
# (3313, 7)

# %%
google_stock.size #total no of elements in DataFrame
# Out:
# 23191

# %%
google_stock.ndim #no of axes, 1 is row and 1 is column
# Out:
# 2

# %%
google_stock.memory_usage() #memory usage by each column
# Out:
# Index           80
# Date         26504
# Open         26504
# High         26504
# Low          26504
# Close        26504
# Adj Close    26504
# Volume       26504
# dtype: int64

# %%
google_stock.at[4, 'High']
# Out:
# 53.651051

# %%
google_stock.loc[4, 'High'] # at or loc are same; 4 repesents index so here 5th row
# Out:
# 53.651051

# %%
google_stock.iat[4, 3]
# Out:
# 51.604362

# %%
google_stock.iloc[4, 3] # iat or iloc are same
# Out:
# 51.604362

# %%
google_stock.loc[:,['High']]
# Out:
#             High
# 0      51.693783
# 1      54.187561
# 2      56.373344
# 3      55.439419
# 4      53.651051
# 5      53.626213
# 6      53.959049
# 7      52.404160
# 8      51.519913
# 9      51.152302
# 10     50.854240
# 11     50.541279
# 12     50.670437
# 13     51.182110
# 14     51.023144
# 15     52.935703
# 16     53.854729
# 17     55.638126
# 18     56.745922
# 19     57.525848
# 20     58.365391
# 21     60.407108
# 22     59.820923
# 23     59.448345
# 24     60.918781
# 25     61.649033
# 26     60.049435
# 27     63.288372
# 28     67.073753
# 29     65.722542
# ...          ...
# 3283  942.479980
# 3284  937.000000
# 3285  930.914978
# 3286  936.409973
# 3287  936.989990
# 3288  938.380005
# 3289  933.479980
# 3290  937.250000
# 3291  932.770020
# 3292  926.489990
# 3293  922.080017
# 3294  922.419983
# 3295  933.880005
# 3296  936.530029
# 3297  934.729980
# 3298  926.400024
# 3299  930.820007
# 3300  949.900024
# 3301  950.690002
# 3302  959.786011
# ...

# %%
google_stock.loc[:, ['High', 'Low']]
# Out:
#             High         Low
# 0      51.693783   47.669952
# 1      54.187561   49.925285
# 2      56.373344   54.172661
# 3      55.439419   51.450363
# 4      53.651051   51.604362
# 5      53.626213   51.991844
# 6      53.959049   52.503513
# 7      52.404160   50.675404
# 8      51.519913   50.749920
# 9      51.152302   49.512966
# 10     50.854240   49.150326
# 11     50.541279   49.339096
# 12     50.670437   49.483158
# 13     51.182110   49.925285
# 14     51.023144   50.173668
# 15     52.935703   50.322701
# 16     53.854729   52.886028
# 17     55.638126   53.049961
# 18     56.745922   54.743942
# 19     57.525848   55.464260
# 20     58.365391   56.408119
# 21     60.407108   58.007717
# 22     59.820923   58.375324
# 23     59.448345   58.027588
# 24     60.918781   58.131908
# 25     61.649033   59.493053
# 26     60.049435   58.519386
# 27     63.288372   59.716602
# 28     67.073753   62.707150
# 29     65.722542   64.083199
# ...          ...         ...
# ...

# %%
google_stock.loc[4, ['Close', 'Adj Close']]
# Out:
# Close        52.6575
# Adj Close    52.6575
# Name: 4, dtype: object

# %%
google_stock.values
# Out:
# array([['8/19/2004', 49.676899, 51.693783, ..., 49.845802, 49.845802,
#         44994500],
#        ['8/20/2004', 50.178635, 54.187560999999995, ..., 53.80505,
#         53.80505, 23005800],
#        ['8/23/2004', 55.017166, 56.373343999999996, ..., 54.346527,
#         54.346527, 18393200],
#        ...,
#        ['10/11/2017', 973.7199710000001, 990.7100220000001, ..., 989.25,
#         989.25, 1693300],
#        ['10/12/2017', 987.4500119999999, 994.1199949999999, ...,
#         987.830017, 987.830017, 1262400],
#        ['10/13/2017', 992.0, 997.2100220000001, ..., 989.679993,
#         989.679993, 1157700]], dtype=object)

# %%
google_stock['High']
# Out:
# 0        51.693783
# 1        54.187561
# 2        56.373344
# 3        55.439419
# 4        53.651051
# 5        53.626213
# 6        53.959049
# 7        52.404160
# 8        51.519913
# 9        51.152302
# 10       50.854240
# 11       50.541279
# 12       50.670437
# 13       51.182110
# 14       51.023144
# 15       52.935703
# 16       53.854729
# 17       55.638126
# 18       56.745922
# 19       57.525848
# 20       58.365391
# 21       60.407108
# 22       59.820923
# 23       59.448345
# 24       60.918781
# 25       61.649033
# 26       60.049435
# 27       63.288372
# 28       67.073753
# 29       65.722542
#            ...
# 3283    942.479980
# 3284    937.000000
# 3285    930.914978
# 3286    936.409973
# 3287    936.989990
# 3288    938.380005
# 3289    933.479980
# 3290    937.250000
# 3291    932.770020
# 3292    926.489990
# 3293    922.080017
# 3294    922.419983
# 3295    933.880005
# 3296    936.530029
# 3297    934.729980
# 3298    926.400024
# ...

# %%
google_stock['High'].max()
# Out:
# 997.2100220000001

# %%
google_stock[['High', 'Close']]
# Out:
#             High       Close
# 0      51.693783   49.845802
# 1      54.187561   53.805050
# 2      56.373344   54.346527
# 3      55.439419   52.096165
# 4      53.651051   52.657513
# 5      53.626213   53.606342
# 6      53.959049   52.732029
# 7      52.404160   50.675404
# 8      51.519913   50.854240
# 9      51.152302   49.801090
# 10     50.854240   50.427021
# 11     50.541279   49.681866
# 12     50.670437   50.461796
# 13     51.182110   50.819469
# 14     51.023144   50.824436
# 15     52.935703   52.324677
# 16     53.854729   53.402668
# 17     55.638126   55.384777
# 18     56.745922   55.638126
# 19     57.525848   56.616764
# 20     58.365391   58.365391
# 21     60.407108   59.294346
# 22     59.820923   58.539257
# 23     59.448345   58.807514
# 24     60.918781   60.019630
# 25     61.649033   59.527828
# 26     60.049435   58.747902
# 27     63.288372   63.020115
# 28     67.073753   65.116478
# 29     65.722542   64.381264
# ...          ...         ...
# ...

# %%
google_stock.loc[[4,5], ['High']]
# Out:
#         High
# 4  53.651051
# 5  53.626213

# %%
google_stock.loc[[1,5], ['High', 'Low']]
# Out:
#         High        Low
# 1  54.187561  49.925285
# 5  53.626213  51.991844

# %%
google_stock.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0  8/19/2004  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 1  8/20/2004  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2  8/23/2004  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 3  8/24/2004  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 4  8/25/2004  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
google_stock.iloc[:25]
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0   8/19/2004  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 1   8/20/2004  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2   8/23/2004  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 3   8/24/2004  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 4   8/25/2004  52.140873  53.651051  51.604362  52.657513  52.657513   9257400
# 5   8/26/2004  52.135906  53.626213  51.991844  53.606342  53.606342   7148200
# 6   8/27/2004  53.700729  53.959049  52.503513  52.732029  52.732029   6258300
# 7   8/30/2004  52.299839  52.404160  50.675404  50.675404  50.675404   5235700
# 8   8/31/2004  50.819469  51.519913  50.749920  50.854240  50.854240   4954800
# 9    9/1/2004  51.018177  51.152302  49.512966  49.801090  49.801090   9206800
# 10   9/2/2004  49.274517  50.854240  49.150326  50.427021  50.427021  15232100
# ...

# %%
google_stock.loc[:25, ['High', 'Low']]
# Out:
#          High        Low
# 0   51.693783  47.669952
# 1   54.187561  49.925285
# 2   56.373344  54.172661
# 3   55.439419  51.450363
# 4   53.651051  51.604362
# 5   53.626213  51.991844
# 6   53.959049  52.503513
# 7   52.404160  50.675404
# 8   51.519913  50.749920
# 9   51.152302  49.512966
# 10  50.854240  49.150326
# 11  50.541279  49.339096
# 12  50.670437  49.483158
# 13  51.182110  49.925285
# 14  51.023144  50.173668
# 15  52.935703  50.322701
# 16  53.854729  52.886028
# 17  55.638126  53.049961
# 18  56.745922  54.743942
# 19  57.525848  55.464260
# 20  58.365391  56.408119
# 21  60.407108  58.007717
# 22  59.820923  58.375324
# 23  59.448345  58.027588
# 24  60.918781  58.131908
# 25  61.649033  59.493053

# %%
google_stock['High'][2]
# Out:
# 56.373343999999996

# %%
google_stock.loc[2]
# Out:
# Date         8/23/2004
# Open           55.0172
# High           56.3733
# Low            54.1727
# Close          54.3465
# Adj Close      54.3465
# Volume        18393200
# Name: 2, dtype: object

# %% [markdown]
# ###### checking datatypes

# %%
google_stock.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
google_stock.get_dtype_counts()
# Out:
# float64    5
# int64      1
# object     1
# dtype: int64

# %%
google_stock.select_dtypes(exclude= object)
# Out:
#             Open        High         Low       Close   Adj Close    Volume
# 0      49.676899   51.693783   47.669952   49.845802   49.845802  44994500
# 1      50.178635   54.187561   49.925285   53.805050   53.805050  23005800
# 2      55.017166   56.373344   54.172661   54.346527   54.346527  18393200
# 3      55.260582   55.439419   51.450363   52.096165   52.096165  15361800
# 4      52.140873   53.651051   51.604362   52.657513   52.657513   9257400
# 5      52.135906   53.626213   51.991844   53.606342   53.606342   7148200
# 6      53.700729   53.959049   52.503513   52.732029   52.732029   6258300
# 7      52.299839   52.404160   50.675404   50.675404   50.675404   5235700
# 8      50.819469   51.519913   50.749920   50.854240   50.854240   4954800
# 9      51.018177   51.152302   49.512966   49.801090   49.801090   9206800
# 10     49.274517   50.854240   49.150326   50.427021   50.427021  15232100
# ...

# %%
google_stock.select_dtypes(include= float) #select all columns whose dtype is float
# Out:
#             Open        High         Low       Close   Adj Close
# 0      49.676899   51.693783   47.669952   49.845802   49.845802
# 1      50.178635   54.187561   49.925285   53.805050   53.805050
# 2      55.017166   56.373344   54.172661   54.346527   54.346527
# 3      55.260582   55.439419   51.450363   52.096165   52.096165
# 4      52.140873   53.651051   51.604362   52.657513   52.657513
# 5      52.135906   53.626213   51.991844   53.606342   53.606342
# 6      53.700729   53.959049   52.503513   52.732029   52.732029
# 7      52.299839   52.404160   50.675404   50.675404   50.675404
# 8      50.819469   51.519913   50.749920   50.854240   50.854240
# 9      51.018177   51.152302   49.512966   49.801090   49.801090
# 10     49.274517   50.854240   49.150326   50.427021   50.427021
# 11     50.148830   50.541279   49.339096   49.681866   49.681866
# 12     50.178635   50.670437   49.483158   50.461796   50.461796
# ...

# %%
google_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 7 columns):
# Date         3313 non-null object
# Open         3313 non-null float64
# High         3313 non-null float64
# Low          3313 non-null float64
# Close        3313 non-null float64
# Adj Close    3313 non-null float64
# Volume       3313 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 181.3+ KB

# %% [markdown]
# unique elements of each column

# %%
np.unique(google_stock['Date'])
# Out:
# array(['1/10/2005', '1/10/2006', '1/10/2007', ..., '9/9/2014', '9/9/2015',
#        '9/9/2016'], dtype=object)

# %% [markdown]
# astype

# %%
google_stock['High'] = google_stock['High'].astype('object')

# %%
google_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 7 columns):
# Date         3313 non-null object
# Open         3313 non-null float64
# High         3313 non-null object
# Low          3313 non-null float64
# Close        3313 non-null float64
# Adj Close    3313 non-null float64
# Volume       3313 non-null int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 181.3+ KB

# %%
google_stock['Low'].nbytes
# Out:
# 26504

# %%
google_stock['High'] = google_stock['High'].astype('category')

# %%
google_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 7 columns):
# Date         3313 non-null object
# Open         3313 non-null float64
# High         3313 non-null category
# Low          3313 non-null float64
# Close        3313 non-null float64
# Adj Close    3313 non-null float64
# Volume       3313 non-null int64
# dtypes: category(1), float64(4), int64(1), object(1)
# memory usage: 346.8+ KB

# %%
google_stock['High'].nbytes
# Out:
# 32170

# %%
google_stock.drop(['High'], axis=1)
# Out:
#             Date        Open         Low       Close   Adj Close    Volume
# 0      8/19/2004   49.676899   47.669952   49.845802   49.845802  44994500
# 1      8/20/2004   50.178635   49.925285   53.805050   53.805050  23005800
# 2      8/23/2004   55.017166   54.172661   54.346527   54.346527  18393200
